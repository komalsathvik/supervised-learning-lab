# %%
print("supervised learning")
# Out:
# supervised learning

# %%
import pandas as pd
data=pd.read_csv("HousePricePrediction.csv")

# %%
print(data)
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# ...

# %%
print(data["MSZoning"].unique())
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']

# %%
print(data["MSZoning"].isna().any())
# Out:
# False

# %%
#since it contains NAN i will be replacing it with the MODE OF THE DATA
data["MSZoning"]=data["MSZoning"].fillna('RL')

# %%
print(data["MSZoning"].isna().any())
# Out:
# False

# %%
print(data["LotConfig"].unique())
# Out:
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']

# %%
x=data.drop("SalePrice",axis=1)
y=data["SalePrice"]

# %%
print(y)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 2914         NaN
# 2915         NaN
# 2916         NaN
# 2917         NaN
# 2918         NaN
# Name: SalePrice, Length: 2919, dtype: float64

# %%
cols = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
x = pd.get_dummies(x, columns=cols, drop_first=True)
#the above code is for ONE HOT ENCODING WHERE WE USUALLY SPLIT ONE COL WHICH HAS MULTIPLE VALUES INTO THESE VARIOUS COLS BY DROPING ONE COL TO REDUCE THE MUTLICOLLINEARITY !!!

# %%
y=y.fillna(y.mean())

# %%
print(x)
# Out:
#         Id  MSSubClass  LotArea BldgType  OverallCond  YearBuilt  \
# 0        0          60     8450     1Fam            5       2003
# 1        1          20     9600     1Fam            8       1976
# 2        2          60    11250     1Fam            5       2001
# 3        3          70     9550     1Fam            5       1915
# 4        4          60    14260     1Fam            5       2000
# ...    ...         ...      ...      ...          ...        ...
# 2914  2914         160     1936    Twnhs            7       1970
# 2915  2915         160     1894   TwnhsE            5       1970
# 2916  2916          20    20000     1Fam            7       1960
# 2917  2917          85    10441     1Fam            5       1992
# 2918  2918          60     9627     1Fam            5       1993
#
#       YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  MSZoning_FV  \
# 0             2003     VinylSd         0.0        856.0        False
# ...

# %%
print(x)
# Out:
#         Id  MSSubClass  LotArea BldgType  OverallCond  YearBuilt  \
# 0        0          60     8450     1Fam            5       2003
# 1        1          20     9600     1Fam            8       1976
# 2        2          60    11250     1Fam            5       2001
# 3        3          70     9550     1Fam            5       1915
# 4        4          60    14260     1Fam            5       2000
# ...    ...         ...      ...      ...          ...        ...
# 2914  2914         160     1936    Twnhs            7       1970
# 2915  2915         160     1894   TwnhsE            5       1970
# 2916  2916          20    20000     1Fam            7       1960
# 2917  2917          85    10441     1Fam            5       1992
# 2918  2918          60     9627     1Fam            5       1993
#
#       YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  LotConfig_CulDSac  \
# 0             2003     VinylSd         0.0        856.0              False
# ...

# %%
print(x)
# Out:
#         Id  MSSubClass  LotArea BldgType  OverallCond  YearBuilt  \
# 0        0          60     8450     1Fam            5       2003
# 1        1          20     9600     1Fam            8       1976
# 2        2          60    11250     1Fam            5       2001
# 3        3          70     9550     1Fam            5       1915
# 4        4          60    14260     1Fam            5       2000
# ...    ...         ...      ...      ...          ...        ...
# 2914  2914         160     1936    Twnhs            7       1970
# 2915  2915         160     1894   TwnhsE            5       1970
# 2916  2916          20    20000     1Fam            7       1960
# 2917  2917          85    10441     1Fam            5       1992
# 2918  2918          60     9627     1Fam            5       1993
#
#       YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  LotConfig_CulDSac  \
# 0             2003     VinylSd         0.0        856.0              False
# ...

# %%
#data preprocessing and setting up takes more time

# %%
y["SalePrice"]=data["SalePrice"]

# %%
print(y.shape[0])
# Out:
# 2920

# %%
print(y["SalePrice"])
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 2914         NaN
# 2915         NaN
# 2916         NaN
# 2917         NaN
# 2918         NaN
# Name: SalePrice, Length: 2919, dtype: float64

# %%
y["SalePrice"]=y["SalePrice"].fillna(y["SalePrice"].mean())

# %%
print(y)
# Out:
# 0                                                     208500.0
# 1                                                     181500.0
# 2                                                     223500.0
# 3                                                     140000.0
# 4                                                     250000.0
#                                    ...
# 2915                                                       NaN
# 2916                                                       NaN
# 2917                                                       NaN
# 2918                                                       NaN
# SalePrice    0       208500.00000
# 1       181500.00000
# 2   ...
# Name: SalePrice, Length: 2920, dtype: object

# %%
print(y["SalePrice"].isna())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2914    False
# 2915    False
# 2916    False
# 2917    False
# 2918    False
# Name: SalePrice, Length: 2919, dtype: bool

# %%
print(x.head)
# Out:
# <bound method NDFrame.head of         Id  MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# 0        0          60     8450            5       2003          2003
# 1        1          20     9600            8       1976          1976
# 2        2          60    11250            5       2001          2002
# 3        3          70     9550            5       1915          1970
# 4        4          60    14260            5       2000          2000
# ...    ...         ...      ...          ...        ...           ...
# 2914  2914         160     1936            7       1970          1970
# 2915  2915         160     1894            5       1970          1970
# 2916  2916          20    20000            7       1960          1996
# 2917  2917          85    10441            5       1992          1992
# 2918  2918          60     9627            5       1993          1994
#
#       BsmtFinSF2  TotalBsmtSF  MSZoning_FV  MSZoning_RH  ...  \
# ...

# %%
print(y.head)
# Out:
# <bound method NDFrame.head of 0                                                     208500.0
# 1                                                     181500.0
# 2                                                     223500.0
# 3                                                     140000.0
# 4                                                     250000.0
#                                    ...
# 2915                                                       NaN
# 2916                                                       NaN
# 2917                                                       NaN
# 2918                                                       NaN
# SalePrice    0       208500.00000
# 1       181500.00000
# 2   ...
# Name: SalePrice, Length: 2920, dtype: object>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
# ...

# %%
y=data["SalePrice"]

# %%
print(y)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 2914         NaN
# 2915         NaN
# 2916         NaN
# 2917         NaN
# 2918         NaN
# Name: SalePrice, Length: 2919, dtype: float64

# %%
# y = y.reset_index(drop=True)
# x = x.reset_index(drop=True)
y.fillna(y.mean())
# Out:
# 0       208500.00000
# 1       181500.00000
# 2       223500.00000
# 3       140000.00000
# 4       250000.00000
#             ...
# 2914    180921.19589
# 2915    180921.19589
# 2916    180921.19589
# 2917    180921.19589
# 2918    180921.19589
# Name: SalePrice, Length: 2919, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
#     579     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
# ...
